# %%
from google.colab import drive
import os
MOUNTPOINT = '/content/gdrive'
drive.mount(MOUNTPOINT)
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !git clone https://github.com/Angeloschert/CSC490_Braindon.git
# Out:
# fatal: destination path 'CSC490_Braindon' already exists and is not an empty directory.

# %%
# !pip install numpy scipy torch nibabel simpleITK crfseg
# Out:
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (1.19.5)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (1.10.0+cu111)
# Requirement already satisfied: nibabel in /usr/local/lib/python3.7/dist-packages (3.0.2)
# Requirement already satisfied: simpleITK in /usr/local/lib/python3.7/dist-packages (2.1.1)
# Requirement already satisfied: crfseg in /usr/local/lib/python3.7/dist-packages (1.0.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch) (3.10.0.2)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from crfseg) (0.11.1+cu111)
# Requirement already satisfied: pillow!=8.3.0,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->crfseg) (7.1.2)

# %%
import sys
sys.path.append('/content/CSC490_Braindon/')

# %%
# !rm -rf result17
# !mkdir result17
# !mkdir result17/HGG
# !mkdir result17/LGG

# %%
gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData
CSC490_Braindon/
# Out:
#   File "<ipython-input-9-20df162f25bd>", line 2
#     CSC490_Braindon/
#                     ^
# SyntaxError: invalid syntax

# %%
from util.train_test_func import *

# %%
import torch
import torch.nn as nn
from crfseg import CRF

crf_model = nn.Sequential(
    nn.Identity(),
    CRF(n_spatial_dims=3)
)

def expand_n_channels(batch_size, n_channel, final_label):
    spatial = tuple(final_label.shape)
    result = np.zeros((batch_size, n_channel) + final_label.shape)
    for i in range(batch_size):
        for j in range(n_channel):
            result[i, j, :, :] = final_label
    return result

# %%
from __future__ import absolute_import, print_function
import numpy as np
from scipy import ndimage
import time
import os
import sys
import torch
from util.data_loader import *
from util.data_process import *
from util.parse_config import parse_config
from util.train_test_func import *
from util.MSNet import MSNet

class NetFactory(object):
    @staticmethod
    def create(name):
        if name == 'MSNet':
            return MSNet
        # add your own networks here
        print('unsupported network:', name)
        exit()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
config_file = 'CSC490_Braindon/config17/test_wt.txt'

# 1, load configure file
config = parse_config(config_file)
config_data = config.get('data')
config_net1 = config.get('network1', None)
config_net2 = config.get('network2', None)
config_net3 = config.get('network3', None)
config_test = config.get('testing')
batch_size = config_test.get('batch_size', 5)

# 2.1, network for whole tumor
if (config_net1):
    print("Has net1")
    net_type1 = config_net1['net_type']
    net_name1 = config_net1['net_name']
    data_shape1 = config_net1['data_shape']
    label_shape1 = config_net1['label_shape']
    class_num1 = config_net1['class_num']
    model_save_prefix1 = "CSC490_Braindon/" + config_net1['model_save_prefix'] + ".pt"

    # construct graph for 1st network
    full_data_shape1 = [batch_size] + data_shape1
    
    net_class1 = NetFactory.create(net_type1)
    net1 = net_class1(num_classes=class_num1, w_reg=None,
                      b_reg=None, in_chns=full_data_shape1[-1])
    net1.load_state_dict(torch.load(model_save_prefix1, map_location=device)["model_state_dict"])
else:
    print("No net 1")
    config_net1ax = config['network1ax']
    config_net1sg = config['network1sg']
    config_net1cr = config['network1cr']

    # construct graph for 1st network axial
    net_type1ax = config_net1ax['net_type']
    net_name1ax = config_net1ax['net_name']
    data_shape1ax = config_net1ax['data_shape']
    label_shape1ax = config_net1ax['label_shape']
    class_num1ax = config_net1ax['class_num']
    model_save_prefix1ax = config_net1ax['model_save_prefix'] + ".pt"

    full_data_shape1ax = [batch_size] + data_shape1ax
    net_class1ax = NetFactory.create(net_type1ax)
    net1ax = net_class1ax(num_classes=class_num1ax, w_reg=None,
                          b_reg=None, in_chns=full_data_shape1ax[-1])
    net1ax.load_state_dict(torch.load(model_save_prefix1ax, map_location=device)["model_state_dict"])

    # construct graph for 1st network sagittal
    net_type1sg = config_net1sg['net_type']
    net_name1sg = config_net1sg['net_name']
    data_shape1sg = config_net1sg['data_shape']
    label_shape1sg = config_net1sg['label_shape']
    class_num1sg = config_net1sg['class_num']
    model_save_prefix1sg = config_net1sg['model_save_prefix'] + ".pt"

    full_data_shape1sg = [batch_size] + data_shape1sg
    net_class1sg = NetFactory.create(net_type1sg)
    net1sg = net_class1sg(num_classes=class_num1sg, w_reg=None,
                          b_reg=None, in_chns=full_data_shape1sg[-1])
    net1sg.load_state_dict(torch.load(model_save_prefix1sg, map_location=device)["model_state_dict"])

    # construct graph for 1st network corogal
    net_type1cr = config_net1cr['net_type']
    net_name1cr = config_net1cr['net_name']
    data_shape1cr = config_net1cr['data_shape']
    label_shape1cr = config_net1cr['label_shape']
    class_num1cr = config_net1cr['class_num']
    model_save_prefix1cr = config_net1cr['model_save_prefix'] + ".pt"

    full_data_shape1cr = [batch_size] + data_shape1cr
    net_class1cr = NetFactory.create(net_type1cr)
    net1cr = net_class1cr(num_classes=class_num1cr, w_reg=None,
                          b_reg=None, in_chns=full_data_shape1cr[-1])
    net1cr.load_state_dict(torch.load(model_save_prefix1cr, map_location=device)["model_state_dict"])

if (config_test.get('whole_tumor_only', False) is False):
    # 2.2, networks for tumor core
    if (config_net2):
        net_type2 = config_net2['net_type']
        net_name2 = config_net2['net_name']
        data_shape2 = config_net2['data_shape']
        label_shape2 = config_net2['label_shape']
        class_num2 = config_net2['class_num']
        model_save_prefix2 = "CSC490_Braindon/" + config_net2['model_save_prefix'] + ".pt"

        # construct graph for 2st network
        full_data_shape2 = [batch_size] + data_shape2
        net_class2 = NetFactory.create(net_type2)
        net2 = net_class2(num_classes=class_num2, w_reg=None,
                          b_reg=None, in_chns=full_data_shape2[-1])
        net2.load_state_dict(torch.load(model_save_prefix2, map_location=device)["model_state_dict"])
    else:
        config_net2ax = config['network2ax']
        config_net2sg = config['network2sg']
        config_net2cr = config['network2cr']

        # construct graph for 2st network axial
        net_type2ax = config_net2ax['net_type']
        net_name2ax = config_net2ax['net_name']
        data_shape2ax = config_net2ax['data_shape']
        label_shape2ax = config_net2ax['label_shape']
        class_num2ax = config_net2ax['class_num']
        model_save_prefix2ax = config_net2ax['model_save_prefix'] + ".pt"

        full_data_shape2ax = [batch_size] + data_shape2ax

        net_class2ax = NetFactory.create(net_type2ax)
        net2ax = net_class2ax(num_classes=class_num2ax, w_reg=None,
                              b_reg=None, in_chns=full_data_shape2ax[-1])
        net2ax.load_state_dict(torch.load(model_save_prefix2ax, map_location=device)["model_state_dict"])

        # construct graph for 2st network sagittal
        net_type2sg = config_net2sg['net_type']
        net_name2sg = config_net2sg['net_name']
        data_shape2sg = config_net2sg['data_shape']
        label_shape2sg = config_net2sg['label_shape']
        class_num2sg = config_net2sg['class_num']
        model_save_prefix2sg = config_net2sg['model_save_prefix'] + ".pt"

        full_data_shape2sg = [batch_size] + data_shape2sg
        net_class2sg = NetFactory.create(net_type2sg)
        net2sg = net_class2sg(num_classes=class_num2sg, w_reg=None,
                              b_reg=None, in_chns=full_data_shape2sg[-1])
        net2sg.load_state_dict(torch.load(model_save_prefix2sg, map_location=device)["model_state_dict"])

        # construct graph for 2st network corogal
        net_type2cr = config_net2cr['net_type']
        net_name2cr = config_net2cr['net_name']
        data_shape2cr = config_net2cr['data_shape']
        label_shape2cr = config_net2cr['label_shape']
        class_num2cr = config_net2cr['class_num']
        model_save_prefix2cr = config_net2cr['model_save_prefix'] + ".pt"

        full_data_shape2cr = [batch_size] + data_shape2cr
        net_class2cr = NetFactory.create(net_type2cr)
        net2cr = net_class2cr(num_classes=class_num2cr, w_reg=None,
                              b_reg=None, in_chns=full_data_shape2cr[-1])
        net2cr.load_state_dict(torch.load(model_save_prefix2cr, map_location=device)["model_state_dict"])
        

    # 2.3, networks for enhanced tumor
    if (config_net3):
        net_type3 = config_net3['net_type']
        net_name3 = config_net3['net_name']
        data_shape3 = config_net3['data_shape']
        label_shape3 = config_net3['label_shape']
        class_num3 = config_net3['class_num']
        model_save_prefix3 = "CSC490_Braindon/" + config_net1['model_save_prefix'] + ".pt"

        # construct graph for 3st network
        full_data_shape3 = [batch_size] + data_shape3
        net_class3 = NetFactory.create(net_type3)
        net3 = net_class3(num_classes=class_num3, w_reg=None,b_reg=None, in_chns=full_data_shape3[-1])
        net3.load_state_dict(torch.load(model_save_prefix3, map_location=device)["model_state_dict"])
    else:
        config_net3ax = config['network3ax']
        config_net3sg = config['network3sg']
        config_net3cr = config['network3cr']

        # construct graph for 3st network axial
        net_type3ax = config_net3ax['net_type']
        net_name3ax = config_net3ax['net_name']
        data_shape3ax = config_net3ax['data_shape']
        label_shape3ax = config_net3ax['label_shape']
        class_num3ax = config_net3ax['class_num']
        model_save_prefix3ax = config_net3ax['model_save_prefix'] + ".pt"

        full_data_shape3ax = [batch_size] + data_shape3ax
        net_class3ax = NetFactory.create(net_type3ax)
        net3ax = net_class3ax(num_classes=class_num3ax, w_reg=None,
                              b_reg=None, in_chns=full_data_shape3ax[-1])
        net3ax.load_state_dict(torch.load(model_save_prefix3ax, map_location=device)["model_state_dict"])

        # construct graph for 3st network sagittal
        net_type3sg = config_net3sg['net_type']
        net_name3sg = config_net3sg['net_name']
        data_shape3sg = config_net3sg['data_shape']
        label_shape3sg = config_net3sg['label_shape']
        class_num3sg = config_net3sg['class_num']
        model_save_prefix3sg = config_net3sg['model_save_prefix'] + ".pt"

        # construct graph for 3st network
        full_data_shape3sg = [batch_size] + data_shape3sg
        net_class3sg = NetFactory.create(net_type3sg)
        net3sg = net_class3sg(num_classes=class_num3sg, w_reg=None,
                              b_reg=None, in_chns=full_data_shape3sg[-1])
        net3sg.load_state_dict(torch.load(model_save_prefix3sg, map_location=device)["model_state_dict"])

        # construct graph for 3st network corogal
        net_type3cr = config_net3cr['net_type']
        net_name3cr = config_net3cr['net_name']
        data_shape3cr = config_net3cr['data_shape']
        label_shape3cr = config_net3cr['label_shape']
        class_num3cr = config_net3cr['class_num']
        model_save_prefix3cr = config_net3cr['model_save_prefix'] + ".pt"

        # construct graph for 3st network
        full_data_shape3cr = [batch_size] + data_shape3cr
        net_class3cr = NetFactory.create(net_type3cr)
        net3cr = net_class3cr(num_classes=class_num3cr, w_reg=None,
                              b_reg=None, in_chns=full_data_shape3cr[-1])
        net3cr.load_state_dict(torch.load(model_save_prefix3cr, map_location=device)["model_state_dict"])

import os
print(os.curdir)
dataloader = DataLoader(config_data)
dataloader.load_data()
image_num = dataloader.get_total_image_number()

# 5, start to test
test_slice_direction = config_test.get('test_slice_direction', 'all')
save_folder = config_data['save_folder']
test_time = []
struct = ndimage.generate_binary_structure(3, 2)
margin = config_test.get('roi_patch_margin', 5)
print("image_num",image_num)

final_labels = []
for i in range(image_num):
    [temp_imgs, temp_weight, temp_name, img_names, temp_bbox, temp_size] = dataloader.get_image_data_with_name(i)
    t0 = time.time()

# ================================== test of 1st network ==================================
    data_shape = None
    if (config_net1):
        data_shapes = [data_shape1[:-1], data_shape1[:-1], data_shape1[:-1]]
        data_shape = data_shape1
        label_shapes = [label_shape1[:-1], label_shape1[:-1], label_shape1[:-1]]
        nets = [net1, net1, net1]
        #inputs = [x1, x1, x1]
        class_num = class_num1
    else:
        data_shapes = [data_shape1ax[:-1], data_shape1sg[:-1], data_shape1cr[:-1]]
        data_shape = data_shape1ax[-1]
        label_shapes = [label_shape1ax[:-1], label_shape1sg[:-1], label_shape1cr[:-1]]
        nets = [net1ax, net1sg, net1cr]
        #inputs = [x1ax, x1sg, x1cr]
        class_num = class_num1ax
    for i in range(len(nets)):
        nets[i] = nets[i].to(device)
    # print('=' * 20, "Going to prediction")
    print("temp imgs: " + str(np.array(temp_imgs).shape))
    print("temp weight: " + str(temp_weight.shape))
    print("temp name: " + str(temp_name))
    print("image names: " + str(img_names))
    print("temp bbox: " + str(temp_bbox))
    print("temp size: " + str(temp_size))
    prob1 = test_one_image_three_nets_adaptive_shape(temp_imgs, data_shapes, label_shapes, data_shape[-1],
                                                     class_num, batch_size, nets, 2)
    print("prob1 size: " + str(prob1.shape))

    # ================== CRF ==================================
    # d, h, w, c = prob1.shape
    # prob1 = prob1.reshape(c, d, h, w)
    # prob1 = np.expand_dims(prob1, axis=0)
    # prob1 = crf_model(torch.tensor(prob1, dtype=torch.float32))
    # print("prob1 size after crf: " + str(prob1.shape))

    # prob1 = prob1.detach().numpy()[0].reshape(d, h, w, c)
    # ===========================================================
    pred1 = np.asarray(np.argmax(prob1, axis=3), np.uint16)
    pred1 = pred1 * temp_weight
    print("pred1 size" + str(pred1.shape))
    # ================================== End of 1st network ==================================



    wt_threshold = 2000
    if (config_test.get('whole_tumor_only', False) is True):
        pred1_lc = ndimage.morphology.binary_closing(pred1, structure=struct)
        print("pred1_lc right after morphology.binary_closing: " + str(pred1_lc.shape))

        pred1_lc = get_largest_two_component(pred1_lc, False, wt_threshold)
        print("pred1_lc right after get_largest_two_component: " + str(pred1_lc.shape))

        out_label = pred1_lc
        print("out_label: " + str(out_label.shape))
    else:
        print("Not whole tumor")



        # ================================== test of 2nd network ==================================
        if (pred1.sum() == 0):
            print('net1 output is null', temp_name)
            bbox1 = get_ND_bounding_box(temp_imgs[0] > 0, margin)
        else:
            pred1_lc = ndimage.morphology.binary_closing(pred1, structure=struct)
            pred1_lc = get_largest_two_component(pred1_lc, False, wt_threshold)
            bbox1 = get_ND_bounding_box(pred1_lc, margin)
        sub_imgs = [crop_ND_volume_with_bounding_box(one_img, bbox1[0], bbox1[1]) for one_img in temp_imgs]
        sub_weight = crop_ND_volume_with_bounding_box(temp_weight, bbox1[0], bbox1[1])
    
        if (config_net2):
            data_shapes = [data_shape2[:-1], data_shape2[:-1], data_shape2[:-1]]
            label_shapes = [label_shape2[:-1], label_shape2[:-1], label_shape2[:-1]]
            nets = [net2, net2, net2]
            #inputs = [x2, x2, x2]
            class_num = class_num2
        else:
            data_shapes = [data_shape2ax[:-1], data_shape2sg[:-1], data_shape2cr[:-1]]
            label_shapes = [label_shape2ax[:-1], label_shape2sg[:-1], label_shape2cr[:-1]]
            nets = [net2ax, net2sg, net2cr]
            #inputs = [x2ax, x2sg, x2cr]
            class_num = class_num2ax
        for i in range(len(nets)):
            nets[i] = nets[i].to(device)
        prob2 = test_one_image_three_nets_adaptive_shape(sub_imgs, data_shapes, label_shapes, data_shape2[-1],
                                                         class_num, batch_size, nets, shape_mode=1)
        print("prob2 size: " + str(prob2.shape))
        
        # ================== CRF ==================================
        # d, h, w, c = prob2.shape
        # prob2 = prob2.reshape(c, d, h, w)
        # prob2 = np.expand_dims(prob2, axis=0)
        # prob2 = crf_model(torch.tensor(prob2, dtype=torch.float32))
        # print("prob2 size after crf: " + str(prob2.shape))

        # prob2 = prob2.detach().numpy()[0].reshape(d, h, w, c)
        # ===========================================================
        pred2 = np.asarray(np.argmax(prob2, axis=3), np.uint16)
        pred2 = pred2 * sub_weight
        print("pred2 size" + str(pred2.shape))
        # ================================== End of 2nd network ==================================
    



        # ================================== test of 3rd network ==================================
        if (pred2.sum() == 0):
            [roid, roih, roiw] = sub_imgs[0].shape
            bbox2 = [[0, 0, 0], [roid - 1, roih - 1, roiw - 1]]
            subsub_imgs = sub_imgs
            subsub_weight = sub_weight
        else:
            pred2_lc = ndimage.morphology.binary_closing(pred2, structure=struct)
            pred2_lc = get_largest_two_component(pred2_lc)
            bbox2 = get_ND_bounding_box(pred2_lc, margin)
            subsub_imgs = [crop_ND_volume_with_bounding_box(one_img, bbox2[0], bbox2[1]) for one_img in sub_imgs]
            subsub_weight = crop_ND_volume_with_bounding_box(sub_weight, bbox2[0], bbox2[1])
    
        if (config_net3):
            data_shapes = [data_shape3[:-1], data_shape3[:-1], data_shape3[:-1]]
            label_shapes = [label_shape3[:-1], label_shape3[:-1], label_shape3[:-1]]
            nets = [net3, net3, net3]
            #inputs = [x3, x3, x3]
            class_num = class_num3
        else:
            data_shapes = [data_shape3ax[:-1], data_shape3sg[:-1], data_shape3cr[:-1]]
            label_shapes = [label_shape3ax[:-1], label_shape3sg[:-1], label_shape3cr[:-1]]
            nets = [net3ax, net3sg, net3cr]
            #inputs = [x3ax, x3sg, x3cr]
            class_num = class_num3ax
        for i in range(len(nets)):
            nets[i] = nets[i].to(device)
        prob3 = test_one_image_three_nets_adaptive_shape(subsub_imgs, data_shapes, label_shapes, data_shape3[-1],
                                                         class_num, batch_size, nets,
                                                         shape_mode=1)
        print("prob3 size: " + str(prob3.shape))
        
        # ================== CRF ==================================
        # d, h, w, c = prob3.shape
        # prob3 = prob3.reshape(c, d, h, w)
        # prob3 = np.expand_dims(prob3, axis=0)
        # prob3 = crf_model(torch.tensor(prob3, dtype=torch.float32))
        # print("prob3 size after crf: " + str(prob3.shape))

        # prob3 = prob3.detach().numpy()[0].reshape(d, h, w, c)
        # ===========================================================
        pred3 = np.asarray(np.argmax(prob3, axis=3), np.uint16)
        pred3 = pred3 * subsub_weight
        print("pred3 size" + str(pred3.shape))
        # ================================== End of 3rd network ==================================



        # 5.4, fuse results at 3 levels
        # convert subsub_label to full size (non-enhanced)
        label3_roi = np.zeros_like(pred2)
        label3_roi = set_ND_volume_roi_with_bounding_box_range(label3_roi, bbox2[0], bbox2[1], pred3)
        label3 = np.zeros_like(pred1)
        label3 = set_ND_volume_roi_with_bounding_box_range(label3, bbox1[0], bbox1[1], label3_roi)
    
        label2 = np.zeros_like(pred1)
        label2 = set_ND_volume_roi_with_bounding_box_range(label2, bbox1[0], bbox1[1], pred2)
    
        label1_mask = (pred1 + label2 + label3) > 0
        label1_mask = ndimage.morphology.binary_closing(label1_mask, structure=struct)
        label1_mask = get_largest_two_component(label1_mask, False, wt_threshold)
        label1 = pred1 * label1_mask
    
        label2_3_mask = (label2 + label3) > 0
        label2_3_mask = label2_3_mask * label1_mask
        label2_3_mask = ndimage.morphology.binary_closing(label2_3_mask, structure=struct)
        label2_3_mask = remove_external_core(label1, label2_3_mask)

        if (label2_3_mask.sum() > 0):
            label2_3_mask = get_largest_two_component(label2_3_mask)

        label1 = (label1 + label2_3_mask) > 0
        label2 = label2_3_mask
        label3 = label2 * label3
        vox_3 = np.asarray(label3 > 0, np.float32).sum()

        if (0 < vox_3 and vox_3 < 30):
            label3 = np.zeros_like(label2)
    
        # 5.5, convert label and save output
        out_label = label1 * 2
        if ('Flair' in config_data['modality_postfix'] and 'mha' in config_data['file_postfix']):
            out_label[label2 > 0] = 3
            out_label[label3 == 1] = 1
            out_label[label3 == 2] = 4
        elif ('flair' in config_data['modality_postfix'] and 'nii' in config_data['file_postfix']):
            out_label[label2 > 0] = 1
            out_label[label3 > 0] = 4
        out_label = np.asarray(out_label, np.int16)


    # print(pred1.sum())
    test_time.append(time.time() - t0)
    final_label = np.zeros(temp_size, np.int16)
    final_label = set_ND_volume_roi_with_bounding_box_range(final_label, temp_bbox[0], temp_bbox[1], out_label)
    final_labels.append((temp_name, final_label))
    print("final_label: " + str(final_label.shape))
    print("\n")

    save_array_as_nifty_volume(final_label, save_folder + "/{0:}.nii.gz".format(temp_name), img_names[0])
# Out:
# data data_root gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData
# data save_folder result17 result17
# data data_names CSC490_Braindon/config17/test_names.txt CSC490_Braindon/config17/test_names.txt
# data modality_postfix [flair, t1, t1ce, t2] ['flair', 't1', 't1ce', 't2']
# data file_postfix nii.gz nii.gz
# network1 net_type MSNet MSNet
# network1 net_name MSNet_1 MSNet_1
# network1 downsample_twice True True
# network1 data_shape [19, 180, 160, 4] [19, 180, 160, 4]
# network1 label_shape [11, 180, 160, 1] [11, 180, 160, 1]
# network1 class_num 2 2
# network1 model_file model17/msnet_1_300.pt model17/msnet_1_300.pt
# network1 model_save_prefix model17/msnet_1_300 model17/msnet_1_300
# network2 net_type MSNet MSNet
# network2 net_name MSNet_2 MSNet_2
# network2 downsample_twice True True
# network2 data_shape [19, 160, 180, 4] [19, 160, 180, 4]
# network2 label_shape [11, 160, 180, 1] [11, 160, 180, 1]
# network2 class_num 2 2
# network2 model_file model17/msnet_2_300.pt model17/msnet_2_300.pt
# network2 model_save_prefix model17/msnet_2_300 model17/msnet_2_300
# network3 net_type MSNet MSNet
# network3 net_name MSNet_3 MSNet_3
# network3 downsample_twice True True
# network3 data_shape [19, 160, 160, 4] [19, 160, 160, 4]
# network3 label_shape [11, 160, 160, 1] [11, 160, 160, 1]
# network3 class_num 2 2
# network3 model_file model17/msnet_3_300.pt model17/msnet_3_300.pt
# network3 model_save_prefix model17/msnet_3_300 model17/msnet_3_300
# testing test_slice_direction all all
# testing whole_tumor_only False False
# Has net1
# .
#
# Data load, 100.0% finished
# image_num 19
# temp imgs: (4, 142, 186, 143)
# temp weight: (142, 186, 143)
# temp name: HGG/Brats17_CBICA_ATX_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_ATX_1/Brats17_CBICA_ATX_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_ATX_1/Brats17_CBICA_ATX_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_ATX_1/Brats17_CBICA_ATX_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_ATX_1/Brats17_CBICA_ATX_1_t2.nii.gz']
# temp bbox: [[0, 35, 47], [141, 220, 189]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 142 186 143
# 142 186 143
# 143 142 186
# 186 142 143
# prob1 size: (142, 186, 143, 2)
# pred1 size(142, 186, 143)
# Not whole tumor
# ======================
# ======================
# 49 44 47
# 49 44 47
# 47 49 44
# 44 49 47
# prob2 size: (49, 44, 47, 2)
# pred2 size(49, 44, 47)
# ======================
# ======================
# 48 43 45
# 48 43 45
# 45 48 43
# 43 48 45
# prob3 size: (48, 43, 45, 2)
# pred3 size(48, 43, 45)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 143, 176, 157)
# temp weight: (143, 176, 157)
# temp name: HGG/Brats17_CBICA_AXN_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AXN_1/Brats17_CBICA_AXN_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AXN_1/Brats17_CBICA_AXN_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AXN_1/Brats17_CBICA_AXN_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AXN_1/Brats17_CBICA_AXN_1_t2.nii.gz']
# temp bbox: [[0, 43, 40], [142, 218, 196]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 143 176 157
# 143 176 157
# 157 143 176
# 176 143 157
# prob1 size: (143, 176, 157, 2)
# pred1 size(143, 176, 157)
# Not whole tumor
# ======================
# ======================
# 96 118 154
# 96 118 154
# 154 96 118
# 118 96 154
# prob2 size: (96, 118, 154, 2)
# pred2 size(96, 118, 154)
# ======================
# ======================
# 56 68 53
# 56 68 53
# 53 56 68
# 68 56 53
# prob3 size: (56, 68, 53, 2)
# pred3 size(56, 68, 53)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 147, 179, 151)
# temp weight: (147, 179, 151)
# temp name: HGG/Brats17_TCIA_491_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_491_1/Brats17_TCIA_491_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_491_1/Brats17_TCIA_491_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_491_1/Brats17_TCIA_491_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_491_1/Brats17_TCIA_491_1_t2.nii.gz']
# temp bbox: [[0, 41, 44], [146, 219, 194]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 147 179 151
# 147 179 151
# 151 147 179
# 179 147 151
# prob1 size: (147, 179, 151, 2)
# pred1 size(147, 179, 151)
# Not whole tumor
# ======================
# ======================
# 83 77 122
# 83 77 122
# 122 83 77
# 77 83 122
# prob2 size: (83, 77, 122, 2)
# pred2 size(83, 77, 122)
# ======================
# ======================
# 81 72 65
# 81 72 65
# 65 81 72
# 72 81 65
# prob3 size: (81, 72, 65, 2)
# pred3 size(81, 72, 65)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 149, 180, 148)
# temp weight: (149, 180, 148)
# temp name: HGG/Brats17_CBICA_AOZ_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AOZ_1/Brats17_CBICA_AOZ_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AOZ_1/Brats17_CBICA_AOZ_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AOZ_1/Brats17_CBICA_AOZ_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AOZ_1/Brats17_CBICA_AOZ_1_t2.nii.gz']
# temp bbox: [[0, 40, 44], [148, 219, 191]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 149 180 148
# 149 180 148
# 148 149 180
# 180 149 148
# prob1 size: (149, 180, 148, 2)
# pred1 size(149, 180, 148)
# Not whole tumor
# ======================
# ======================
# 63 71 62
# 63 71 62
# 62 63 71
# 71 63 62
# prob2 size: (63, 71, 62, 2)
# pred2 size(63, 71, 62)
# ======================
# ======================
# 60 70 61
# 60 70 61
# 61 60 70
# 70 60 61
# prob3 size: (60, 70, 61, 2)
# pred3 size(60, 70, 61)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 145, 163, 148)
# temp weight: (145, 163, 148)
# temp name: HGG/Brats17_TCIA_151_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_151_1/Brats17_TCIA_151_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_151_1/Brats17_TCIA_151_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_151_1/Brats17_TCIA_151_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_151_1/Brats17_TCIA_151_1_t2.nii.gz']
# temp bbox: [[0, 48, 44], [144, 210, 191]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 145 163 148
# 145 163 148
# 148 145 163
# 163 145 148
# prob1 size: (145, 163, 148, 2)
# pred1 size(145, 163, 148)
# Not whole tumor
# ======================
# ======================
# 68 68 54
# 68 68 54
# 54 68 68
# 68 68 54
# prob2 size: (68, 68, 54, 2)
# pred2 size(68, 68, 54)
# ======================
# ======================
# 68 66 54
# 68 66 54
# 54 68 66
# 66 68 54
# prob3 size: (68, 66, 54, 2)
# pred3 size(68, 66, 54)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 145, 164, 154)
# temp weight: (145, 164, 154)
# temp name: HGG/Brats17_2013_25_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_2013_25_1/Brats17_2013_25_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_2013_25_1/Brats17_2013_25_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_2013_25_1/Brats17_2013_25_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_2013_25_1/Brats17_2013_25_1_t2.nii.gz']
# temp bbox: [[4, 41, 42], [148, 204, 195]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 145 164 154
# 145 164 154
# 154 145 164
# 164 145 154
# prob1 size: (145, 164, 154, 2)
# pred1 size(145, 164, 154)
# Not whole tumor
# ======================
# ======================
# 85 95 101
# 85 95 101
# 101 85 95
# 95 85 101
# prob2 size: (85, 95, 101, 2)
# pred2 size(85, 95, 101)
# ======================
# ======================
# 31 40 34
# 31 40 34
# 34 31 40
# 40 31 34
# prob3 size: (31, 40, 34, 2)
# pred3 size(31, 40, 34)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 140, 182, 146)
# temp weight: (140, 182, 146)
# temp name: HGG/Brats17_TCIA_396_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_396_1/Brats17_TCIA_396_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_396_1/Brats17_TCIA_396_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_396_1/Brats17_TCIA_396_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_396_1/Brats17_TCIA_396_1_t2.nii.gz']
# temp bbox: [[6, 38, 46], [145, 219, 191]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 140 182 146
# 140 182 146
# 146 140 182
# 182 140 146
# prob1 size: (140, 182, 146, 2)
# pred1 size(140, 182, 146)
# Not whole tumor
# ======================
# ======================
# 66 101 123
# 66 101 123
# 123 66 101
# 101 66 123
# prob2 size: (66, 101, 123, 2)
# pred2 size(66, 101, 123)
# ======================
# ======================
# 63 90 67
# 63 90 67
# 67 63 90
# 90 63 67
# prob3 size: (63, 90, 67, 2)
# pred3 size(63, 90, 67)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 148, 182, 139)
# temp weight: (148, 182, 139)
# temp name: HGG/Brats17_CBICA_AQN_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AQN_1/Brats17_CBICA_AQN_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AQN_1/Brats17_CBICA_AQN_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AQN_1/Brats17_CBICA_AQN_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_CBICA_AQN_1/Brats17_CBICA_AQN_1_t2.nii.gz']
# temp bbox: [[0, 41, 49], [147, 222, 187]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 148 182 139
# 148 182 139
# 139 148 182
# 182 148 139
# prob1 size: (148, 182, 139, 2)
# pred1 size(148, 182, 139)
# Not whole tumor
# ======================
# ======================
# 50 59 39
# 50 59 39
# 39 50 59
# 59 50 39
# prob2 size: (50, 59, 39, 2)
# pred2 size(50, 59, 39)
# ======================
# ======================
# 50 59 37
# 50 59 37
# 37 50 59
# 59 50 37
# prob3 size: (50, 59, 37, 2)
# pred3 size(50, 59, 37)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 142, 185, 151)
# temp weight: (142, 185, 151)
# temp name: HGG/Brats17_TCIA_135_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_135_1/Brats17_TCIA_135_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_135_1/Brats17_TCIA_135_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_135_1/Brats17_TCIA_135_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_135_1/Brats17_TCIA_135_1_t2.nii.gz']
# temp bbox: [[0, 38, 45], [141, 222, 195]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 142 185 151
# 142 185 151
# 151 142 185
# 185 142 151
# prob1 size: (142, 185, 151, 2)
# pred1 size(142, 185, 151)
# Not whole tumor
# ======================
# ======================
# 66 72 54
# 66 72 54
# 54 66 72
# 72 66 54
# prob2 size: (66, 72, 54, 2)
# pred2 size(66, 72, 54)
# ======================
# ======================
# 66 71 54
# 66 71 54
# 54 66 71
# 71 66 54
# prob3 size: (66, 71, 54, 2)
# pred3 size(66, 71, 54)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 151, 182, 141)
# temp weight: (151, 182, 141)
# temp name: HGG/Brats17_TCIA_603_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_603_1/Brats17_TCIA_603_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_603_1/Brats17_TCIA_603_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_603_1/Brats17_TCIA_603_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/HGG/Brats17_TCIA_603_1/Brats17_TCIA_603_1_t2.nii.gz']
# temp bbox: [[0, 38, 49], [150, 219, 189]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 151 182 141
# 151 182 141
# 141 151 182
# 182 151 141
# prob1 size: (151, 182, 141, 2)
# pred1 size(151, 182, 141)
# Not whole tumor
# ======================
# ======================
# 64 80 63
# 64 80 63
# 63 64 80
# 80 64 63
# prob2 size: (64, 80, 63, 2)
# pred2 size(64, 80, 63)
# ======================
# ======================
# 64 80 62
# 64 80 62
# 62 64 80
# 80 64 62
# prob3 size: (64, 80, 62, 2)
# pred3 size(64, 80, 62)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 135, 175, 151)
# temp weight: (135, 175, 151)
# temp name: LGG/Brats17_2013_24_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_2013_24_1/Brats17_2013_24_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_2013_24_1/Brats17_2013_24_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_2013_24_1/Brats17_2013_24_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_2013_24_1/Brats17_2013_24_1_t2.nii.gz']
# temp bbox: [[5, 42, 44], [139, 216, 194]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 135 175 151
# 135 175 151
# 151 135 175
# 175 135 151
# prob1 size: (135, 175, 151, 2)
# pred1 size(135, 175, 151)
# Not whole tumor
# ======================
# ======================
# 55 80 37
# 55 80 37
# 37 55 80
# 80 55 37
# prob2 size: (55, 80, 37, 2)
# pred2 size(55, 80, 37)
# ======================
# ======================
# 55 68 34
# 55 68 34
# 34 55 68
# 68 55 34
# prob3 size: (55, 68, 34, 2)
# pred3 size(55, 68, 34)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 144, 172, 145)
# temp weight: (144, 172, 145)
# temp name: LGG/Brats17_TCIA_630_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_630_1/Brats17_TCIA_630_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_630_1/Brats17_TCIA_630_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_630_1/Brats17_TCIA_630_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_630_1/Brats17_TCIA_630_1_t2.nii.gz']
# temp bbox: [[1, 46, 46], [144, 217, 190]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 144 172 145
# 144 172 145
# 145 144 172
# 172 144 145
# prob1 size: (144, 172, 145, 2)
# pred1 size(144, 172, 145)
# Not whole tumor
# ======================
# ======================
# 68 63 54
# 68 63 54
# 54 68 63
# 63 68 54
# prob2 size: (68, 63, 54, 2)
# pred2 size(68, 63, 54)
# ======================
# ======================
# 67 51 54
# 67 51 54
# 54 67 51
# 51 67 54
# prob3 size: (67, 51, 54, 2)
# pred3 size(67, 51, 54)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 147, 170, 143)
# temp weight: (147, 170, 143)
# temp name: LGG/Brats17_TCIA_152_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_152_1/Brats17_TCIA_152_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_152_1/Brats17_TCIA_152_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_152_1/Brats17_TCIA_152_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_152_1/Brats17_TCIA_152_1_t2.nii.gz']
# temp bbox: [[0, 41, 48], [146, 210, 190]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 147 170 143
# 147 170 143
# 143 147 170
# 170 147 143
# prob1 size: (147, 170, 143, 2)
# pred1 size(147, 170, 143)
# Not whole tumor
# ======================
# ======================
# 64 65 58
# 64 65 58
# 58 64 65
# 65 64 58
# prob2 size: (64, 65, 58, 2)
# pred2 size(64, 65, 58)
# ======================
# ======================
# 64 64 58
# 64 64 58
# 58 64 64
# 64 64 58
# prob3 size: (64, 64, 58, 2)
# pred3 size(64, 64, 58)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 143, 192, 155)
# temp weight: (143, 192, 155)
# temp name: LGG/Brats17_TCIA_620_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_620_1/Brats17_TCIA_620_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_620_1/Brats17_TCIA_620_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_620_1/Brats17_TCIA_620_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_620_1/Brats17_TCIA_620_1_t2.nii.gz']
# temp bbox: [[0, 34, 42], [142, 225, 196]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 143 192 155
# 143 192 155
# 155 143 192
# 192 143 155
# prob1 size: (143, 192, 155, 2)
# pred1 size(143, 192, 155)
# Not whole tumor
# ======================
# ======================
# 78 155 98
# 78 155 98
# 98 78 155
# 155 78 98
# prob2 size: (78, 155, 98, 2)
# pred2 size(78, 155, 98)
# ======================
# ======================
# 46 155 98
# 46 155 98
# 98 46 155
# 155 46 98
# prob3 size: (46, 155, 98, 2)
# pred3 size(46, 155, 98)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 147, 172, 147)
# temp weight: (147, 172, 147)
# temp name: LGG/Brats17_2013_29_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_2013_29_1/Brats17_2013_29_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_2013_29_1/Brats17_2013_29_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_2013_29_1/Brats17_2013_29_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_2013_29_1/Brats17_2013_29_1_t2.nii.gz']
# temp bbox: [[0, 44, 46], [146, 215, 192]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 147 172 147
# 147 172 147
# 147 147 172
# 172 147 147
# prob1 size: (147, 172, 147, 2)
# pred1 size(147, 172, 147)
# Not whole tumor
# ======================
# ======================
# 58 64 56
# 58 64 56
# 56 58 64
# 64 58 56
# prob2 size: (58, 64, 56, 2)
# pred2 size(58, 64, 56)
# ======================
# ======================
# 55 64 54
# 55 64 54
# 54 55 64
# 64 55 54
# prob3 size: (55, 64, 54, 2)
# pred3 size(55, 64, 54)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 144, 174, 142)
# temp weight: (144, 174, 142)
# temp name: LGG/Brats17_TCIA_490_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_490_1/Brats17_TCIA_490_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_490_1/Brats17_TCIA_490_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_490_1/Brats17_TCIA_490_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_490_1/Brats17_TCIA_490_1_t2.nii.gz']
# temp bbox: [[0, 40, 48], [143, 213, 189]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 144 174 142
# 144 174 142
# 142 144 174
# 174 144 142
# prob1 size: (144, 174, 142, 2)
# pred1 size(144, 174, 142)
# Not whole tumor
# ======================
# ======================
# 72 82 72
# 72 82 72
# 72 72 82
# 82 72 72
# prob2 size: (72, 82, 72, 2)
# pred2 size(72, 82, 72)
# ======================
# ======================
# 56 81 52
# 56 81 52
# 52 56 81
# 81 56 52
# prob3 size: (56, 81, 52, 2)
# pred3 size(56, 81, 52)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 143, 177, 143)
# temp weight: (143, 177, 143)
# temp name: LGG/Brats17_TCIA_449_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_449_1/Brats17_TCIA_449_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_449_1/Brats17_TCIA_449_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_449_1/Brats17_TCIA_449_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_449_1/Brats17_TCIA_449_1_t2.nii.gz']
# temp bbox: [[0, 41, 47], [142, 217, 189]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 143 177 143
# 143 177 143
# 143 143 177
# 177 143 143
# prob1 size: (143, 177, 143, 2)
# pred1 size(143, 177, 143)
# Not whole tumor
# ======================
# ======================
# 93 79 101
# 93 79 101
# 101 93 79
# 79 93 101
# prob2 size: (93, 79, 101, 2)
# pred2 size(93, 79, 101)
# ======================
# ======================
# 51 65 48
# 51 65 48
# 48 51 65
# 65 51 48
# prob3 size: (51, 65, 48, 2)
# pred3 size(51, 65, 48)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 148, 170, 144)
# temp weight: (148, 170, 144)
# temp name: LGG/Brats17_TCIA_634_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_634_1/Brats17_TCIA_634_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_634_1/Brats17_TCIA_634_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_634_1/Brats17_TCIA_634_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_634_1/Brats17_TCIA_634_1_t2.nii.gz']
# temp bbox: [[0, 42, 47], [147, 211, 190]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 148 170 144
# 148 170 144
# 144 148 170
# 170 148 144
# prob1 size: (148, 170, 144, 2)
# pred1 size(148, 170, 144)
# Not whole tumor
# ======================
# ======================
# 72 85 58
# 72 85 58
# 58 72 85
# 85 72 58
# prob2 size: (72, 85, 58, 2)
# pred2 size(72, 85, 58)
# ======================
# ======================
# 72 84 55
# 72 84 55
# 55 72 84
# 84 72 55
# prob3 size: (72, 84, 55, 2)
# pred3 size(72, 84, 55)
# final_label: (155, 240, 240)
#
#
# temp imgs: (4, 146, 180, 147)
# temp weight: (146, 180, 147)
# temp name: LGG/Brats17_TCIA_346_1
# image names: ['gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_346_1/Brats17_TCIA_346_1_flair.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_346_1/Brats17_TCIA_346_1_t1.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_346_1/Brats17_TCIA_346_1_t1ce.nii.gz', 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData/LGG/Brats17_TCIA_346_1/Brats17_TCIA_346_1_t2.nii.gz']
# temp bbox: [[0, 38, 46], [145, 217, 192]]
# temp size: (155, 240, 240)
# ======================
# ======================
# 146 180 147
# 146 180 147
# 147 146 180
# 180 146 147
# prob1 size: (146, 180, 147, 2)
# pred1 size(146, 180, 147)
# Not whole tumor
# ======================
# ======================
# 57 75 42
# 57 75 42
# 42 57 75
# 75 57 42
# prob2 size: (57, 75, 42, 2)
# pred2 size(57, 75, 42)
# ======================
# ======================
# 48 45 27
# 48 45 27
# 27 48 45
# 45 48 27
# prob3 size: (48, 45, 27, 2)
# pred3 size(48, 45, 27)
# final_label: (155, 240, 240)

# %%
# -*- coding: utf-8 -*-

from __future__ import absolute_import, print_function
import os
import sys
sys.path.append('./')
import numpy as np
from util.data_process import load_3d_volume_as_array, binary_dice3d

def get_ground_truth_names(g_folder, patient_names_file):
    with open(patient_names_file) as f:
            content = f.readlines()
            patient_names = [x.strip() for x in content]
    full_gt_names = []
    for patient_name in patient_names:
        patient_dir = os.path.join(g_folder, patient_name)
        img_names   = os.listdir(patient_dir)
        gt_name = None
        for img_name in img_names:
          
              if 'seg.' in img_name:
                  gt_name = img_name
                  break
        gt_name = os.path.join(patient_dir, gt_name)
        full_gt_names.append(gt_name)
    return full_gt_names

def get_segmentation_names(seg_folder, patient_names_file):
    with open(patient_names_file) as f:
            content = f.readlines()
            patient_names = [x.strip() for x in content]
    full_seg_names = []
    for patient_name in patient_names:
        seg_name = os.path.join(seg_folder, patient_name + '.nii.gz')
        full_seg_names.append(seg_name)
    return full_seg_names

def dice_of_brats_data_set(gt_names, seg_names, type_idx):
    assert(len(gt_names) == len(seg_names))
    dice_all_data = []
    for i in range(len(gt_names)):
        g_volume = load_3d_volume_as_array(gt_names[i])
        s_volume = load_3d_volume_as_array(seg_names[i])

        dice_one_volume = []
        if(type_idx ==0): # whole tumor
            temp_dice = binary_dice3d(s_volume > 0, g_volume > 0)
            dice_one_volume = [temp_dice]
        elif(type_idx == 1): # tumor core
            seg_=np.copy(s_volume)
            ground_=np.copy(g_volume)
            seg_[seg_==2]=0
            ground_[ground_==2]=0
            temp_dice = binary_dice3d(seg_ > 0, ground_ > 0)
            dice_one_volume = [temp_dice]
        else: #enhenced tumor
            temp_dice = binary_dice3d(s_volume ==4, g_volume ==4)
            dice_one_volume = [temp_dice]
            
        dice_all_data.append(dice_one_volume)
    return dice_all_data
    
if __name__ == '__main__':
    s_folder = 'result17'

    g_folder = 'gdrive/MyDrive/Schools/CSC490/BRATS2017/Brats17TrainingData'
    # g_folder = 'gdrive/MyDrive/BRATS2017/Brats17TrainingData'
    
    patient_names_file = 'CSC490_Braindon/config17/test_names.txt'
    # patient_names_file = 'CSC490_Braindon/config17/test_names_temp.txt'

    print("="*15,"Segmenting","="*15)
    print("="*15,"Evaluating","="*15)

    test_types = ['whole','core', 'enhenced']
    gt_names  = get_ground_truth_names(g_folder, patient_names_file)
    seg_names = get_segmentation_names(s_folder, patient_names_file)
    for type_idx in range(3):
        dice = dice_of_brats_data_set(gt_names, seg_names, type_idx)
        dice = np.asarray(dice)
        dice_mean = dice.mean(axis = 0)
        dice_std  = dice.std(axis  = 0)
        test_type = test_types[type_idx]
        np.savetxt(s_folder + '/dice_{0:}.txt'.format(test_type), dice)
        np.savetxt(s_folder + '/dice_{0:}_mean.txt'.format(test_type), dice_mean)
        np.savetxt(s_folder + '/dice_{0:}_std.txt'.format(test_type), dice_std)
        print('tissue type', test_type)
        print('dice mean  ', dice_mean)
        print('dice std   ', dice_std)
# Out:
# =============== Segmenting ===============
# =============== Evaluating ===============
# tissue type whole
# dice mean   [0.5057746]
# dice std    [0.26275634]
# tissue type core
# dice mean   [0.2007906]
# dice std    [0.30727264]
# tissue type enhenced
# dice mean   [0.35969062]
# dice std    [0.39052061]

# %%
while True:
  pass
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-648a2bab0435> in <module>()
#       1 while True:
# ----> 2   pass
#
# KeyboardInterrupt:

# %%
# !zip -r /content/result17_no_crf.zip /content/result17
# Out:
#   adding: content/result17/ (stored 0%)
#   adding: content/result17/.ipynb_checkpoints/ (stored 0%)
#   adding: content/result17/dice_whole_std.txt (stored 0%)
#   adding: content/result17/HGG/ (stored 0%)
#   adding: content/result17/HGG/Brats17_2013_25_1.nii.gz (deflated 77%)
#   adding: content/result17/HGG/Brats17_CBICA_AXN_1.nii.gz (deflated 63%)
#   adding: content/result17/HGG/Brats17_CBICA_ATX_1.nii.gz (deflated 74%)
#   adding: content/result17/HGG/Brats17_TCIA_135_1.nii.gz (deflated 52%)
#   adding: content/result17/HGG/Brats17_TCIA_491_1.nii.gz (deflated 56%)
#   adding: content/result17/HGG/Brats17_CBICA_AQN_1.nii.gz (deflated 69%)
#   adding: content/result17/HGG/Brats17_TCIA_151_1.nii.gz (deflated 52%)
#   adding: content/result17/HGG/Brats17_TCIA_396_1.nii.gz (deflated 63%)
#   adding: content/result17/HGG/Brats17_CBICA_AOZ_1.nii.gz (deflated 74%)
#   adding: content/result17/HGG/Brats17_TCIA_603_1.nii.gz (deflated 66%)
#   adding: content/result17/dice_enhenced_std.txt (stored 0%)
#   adding: content/result17/dice_core_mean.txt (stored 0%)
#   adding: content/result17/dice_whole_mean.txt (stored 0%)
#   adding: content/result17/LGG/ (stored 0%)
#   adding: content/result17/LGG/Brats17_2013_29_1.nii.gz (deflated 76%)
#   adding: content/result17/LGG/Brats17_TCIA_310_1.nii.gz (deflated 98%)
#   adding: content/result17/LGG/Brats17_2013_24_1.nii.gz (deflated 81%)
#   adding: content/result17/LGG/Brats17_TCIA_490_1.nii.gz (deflated 54%)
#   adding: content/result17/LGG/Brats17_TCIA_634_1.nii.gz (deflated 75%)
#   adding: content/result17/LGG/Brats17_TCIA_630_1.nii.gz (deflated 78%)
#   adding: content/result17/LGG/Brats17_TCIA_449_1.nii.gz (deflated 59%)
#   adding: content/result17/LGG/Brats17_TCIA_620_1.nii.gz (deflated 74%)
#   adding: content/result17/LGG/Brats17_TCIA_152_1.nii.gz (deflated 69%)
#   adding: content/result17/LGG/Brats17_TCIA_346_1.nii.gz (deflated 80%)
#   adding: content/result17/dice_whole.txt (deflated 51%)
#   adding: content/result17/dice_core_std.txt (stored 0%)
#   adding: content/result17/dice_core.txt (deflated 49%)
#   adding: content/result17/dice_enhenced_mean.txt (stored 0%)
#   adding: content/result17/dice_enhenced.txt (deflated 55%)

# %%
from google.colab import files
files.download("/content/result17_no_crf.zip")
